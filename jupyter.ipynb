# %%
import streamlit as st
import pandas as pd
import plotly.express as px
import numpy as np

# %%
data_import = pd.read_csv("pcra.csv")
data_import
# Out:
#   Patient Fname   Lname Sex  Age of diagnosis  Year of first diagnosis  \
# 0         Tony    Stark   M                 0                     2017
# 1        Peter   Parker   M                 0                     2017
# 2         Steve  Rogers   M                 0                     2018
# 3         Bruce  Banner   M                 0                     2016
# 4        Bucky   Burnes   M                 1                     2016
#
#    Year of second diagnosis  Year of third diagnosis  \
# 0                      2019                     2020
# 1                      2018                     2019
# 2                      2019                     2020
# 3                      2018                     2019
# 4                      2017                     2018
#
#    PSA at diagnosis (ng/ml)  Gleason scode   Clinical stage
# 0                         1               1               0
# 1                         0               0               1
# ...
